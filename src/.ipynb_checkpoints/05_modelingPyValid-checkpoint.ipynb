from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from catboost import CatBoostRegressor, Pool
from ngboost import NGBRegressor
from sklearn.metrics import make_scorer
from sklearn.model_selection import KFold

# %%
def NMAE(true, pred) -> float:
    mae = np.mean(np.abs(true - pred))
    score = mae / np.mean(np.abs(true))
    return score

# %%
nmae_score = make_scorer(NMAE, greater_is_better=False)

# %%
kf = KFold(n_splits = 10, random_state = 42, shuffle = True)

# %%
rf_pred = np.zeros(target.shape[0])
rf_val = []
for n, (tr_idx, val_idx) in enumerate(kf.split(X, y)) :
    print(f'{n + 1} FOLD Training.....')
    tr_x, tr_y = X.iloc[tr_idx], y.iloc[tr_idx]
    val_x, val_y = X.iloc[val_idx], np.expm1(y.iloc[val_idx])
    
    rf = RandomForestRegressor(random_state = 42, criterion = 'mae')
    rf.fit(tr_x, tr_y)
    
    val_pred = np.expm1(rf.predict(val_x))
    val_nmae = NMAE(val_y, val_pred)
    rf_val.append(val_nmae)
    print(f'{n + 1} FOLD NMAE = {val_nmae}\n')
    
    fold_pred = rf.predict(target) / 10
    rf_pred += fold_pred
print(f'10FOLD Mean of NMAE = {np.mean(rf_val)} & std = {np.std(rf_val)}')
# Out:
# 1 FOLD Training.....
# 1 FOLD NMAE = 0.0844100683928693
#
# 2 FOLD Training.....
# 2 FOLD NMAE = 0.10469761757467397
#
# 3 FOLD Training.....
# 3 FOLD NMAE = 0.10159300024833884
#
# 4 FOLD Training.....
# 4 FOLD NMAE = 0.12284490789779805
#
# 5 FOLD Training.....
# 5 FOLD NMAE = 0.09617324196958335
#
# 6 FOLD Training.....
# 6 FOLD NMAE = 0.09499782569598449
#
# 7 FOLD Training.....
# 7 FOLD NMAE = 0.09059950443650648
#
# 8 FOLD Training.....
# 8 FOLD NMAE = 0.10421959191205075
#
# 9 FOLD Training.....
# 9 FOLD NMAE = 0.10425503573549091
#
# 10 FOLD Training.....
# 10 FOLD NMAE = 0.10485432845093107
#
# 10FOLD Mean of NMAE = 0.10086451223142272 & std = 0.009846710935203833

# %%
gbr_pred = np.zeros(target.shape[0])
gbr_val = []
for n, (tr_idx, val_idx) in enumerate(kf.split(X, y)) :
    print(f'{n + 1} FOLD Training.....')
    tr_x, tr_y = X.iloc[tr_idx], y.iloc[tr_idx]
    val_x, val_y = X.iloc[val_idx], np.expm1(y.iloc[val_idx])
    
    gbr = GradientBoostingRegressor(random_state = 42, max_depth = 4, learning_rate = 0.05, n_estimators = 1000)
    gbr.fit(tr_x, tr_y)
    
    val_pred = np.expm1(gbr.predict(val_x))
    val_nmae = NMAE(val_y, val_pred)
    gbr_val.append(val_nmae)
    print(f'{n + 1} FOLD NMAE = {val_nmae}\n')
    
    fold_pred = gbr.predict(target) / 10
    gbr_pred += fold_pred
print(f'10FOLD Mean of NMAE = {np.mean(gbr_val)} & std = {np.std(gbr_val)}')
# Out:
# 1 FOLD Training.....
# 1 FOLD NMAE = 0.08349468604339731
#
# 2 FOLD Training.....
# 2 FOLD NMAE = 0.0973470372583205
#
# 3 FOLD Training.....
# 3 FOLD NMAE = 0.09856276426859621
#
# 4 FOLD Training.....
# 4 FOLD NMAE = 0.11347557449097499
#
# 5 FOLD Training.....
# 5 FOLD NMAE = 0.09124773837718772
#
# 6 FOLD Training.....
# 6 FOLD NMAE = 0.10046034871929486
#
# 7 FOLD Training.....
# 7 FOLD NMAE = 0.09942803743432507
#
# 8 FOLD Training.....
# 8 FOLD NMAE = 0.0951156067139962
#
# 9 FOLD Training.....
# 9 FOLD NMAE = 0.0869594714406881
#
# 10 FOLD Training.....
# 10 FOLD NMAE = 0.09819040126774937
#
# 10FOLD Mean of NMAE = 0.09642816660145302 & std = 0.007809410300008837

# %%
cb_pred = np.zeros(target.shape[0])
cb_val = []
for n, (tr_idx, val_idx) in enumerate(kf.split(X, y)) :
    print(f'{n + 1} FOLD Training.....')
    tr_x, tr_y = X.iloc[tr_idx], y.iloc[tr_idx]
    val_x, val_y = X.iloc[val_idx], np.expm1(y.iloc[val_idx])
    
    tr_data = Pool(data = tr_x, label = tr_y)
    val_data = Pool(data = val_x, label = val_y)
    
    cb = CatBoostRegressor(depth = 4, random_state = 42, loss_function = 'MAE', n_estimators = 3000, learning_rate = 0.03, verbose = 0)
    cb.fit(tr_data, eval_set = val_data, early_stopping_rounds = 750, verbose = 1000)
    
    val_pred = np.expm1(cb.predict(val_x))
    val_nmae = NMAE(val_y, val_pred)
    cb_val.append(val_nmae)
    print(f'{n + 1} FOLD NMAE = {val_nmae}\n')
    
    target_data = Pool(data = target, label = None)
    fold_pred = cb.predict(target) / 10
    cb_pred += fold_pred
print(f'10FOLD Mean of NMAE = {np.mean(cb_val)} & std = {np.std(cb_val)}')
# Out:
# 1 FOLD Training.....
# 0:	learn: 0.2931341	test: 184599.8953464	best: 184599.8953464 (0)	total: 3.68ms	remaining: 11s
# Stopped by overfitting detector  (750 iterations wait)
#
# bestTest = 184599.8379
# bestIteration = 160
#
# Shrink model to first 161 iterations.
# 1 FOLD NMAE = 0.07661230780059615
#
# 2 FOLD Training.....
# 0:	learn: 0.2937850	test: 182774.3366574	best: 182774.3366574 (0)	total: 3.98ms	remaining: 11.9s
# Stopped by overfitting detector  (750 iterations wait)
#
# bestTest = 182774.3159
# bestIteration = 87
#
# Shrink model to first 88 iterations.
# 2 FOLD NMAE = 0.11513412450154048
#
# 3 FOLD Training.....
# 0:	learn: 0.2879067	test: 196831.3019972	best: 196831.3019972 (0)	total: 2.48ms	remaining: 7.45s
# 1000:	learn: 0.0671934	test: 196831.2235266	best: 196831.2205092 (491)	total: 2.17s	remaining: 4.33s
# Stopped by overfitting detector  (750 iterations wait)
#
# bestTest = 196831.2205
# bestIteration = 491
#
# Shrink model to first 492 iterations.
# 3 FOLD NMAE = 0.09536267448150217
#
# 4 FOLD Training.....
# 0:	learn: 0.2908143	test: 172746.7625087	best: 172746.7625087 (0)	total: 4.06ms	remaining: 12.2s
# Stopped by overfitting detector  (750 iterations wait)
#
# bestTest = 172746.7625
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# 4 FOLD NMAE = 0.2947886296393872
#
# 5 FOLD Training.....
# 0:	learn: 0.2915415	test: 194134.6732539	best: 194134.6732539 (0)	total: 1.97ms	remaining: 5.91s
# 1000:	learn: 0.0691564	test: 194134.5800769	best: 194134.5789571 (649)	total: 2.2s	remaining: 4.39s
# Stopped by overfitting detector  (750 iterations wait)
#
# bestTest = 194134.579
# bestIteration = 649
#
# Shrink model to first 650 iterations.
# 5 FOLD NMAE = 0.0882852514383814
#
# 6 FOLD Training.....
# 0:	learn: 0.2893290	test: 197571.5836467	best: 197571.5836467 (0)	total: 5.04ms	remaining: 15.1s
# 1000:	learn: 0.0673691	test: 197571.4825035	best: 197571.4824787 (996)	total: 2.5s	remaining: 5s
# 2000:	learn: 0.0584863	test: 197571.4819441	best: 197571.4815733 (1505)	total: 4.72s	remaining: 2.35s
# Stopped by overfitting detector  (750 iterations wait)
#
# bestTest = 197571.4816
# bestIteration = 1505
#
# Shrink model to first 1506 iterations.
# 6 FOLD NMAE = 0.09987979237051249
#
# 7 FOLD Training.....
# 0:	learn: 0.2930141	test: 183621.5475008	best: 183621.5475008 (0)	total: 4.93ms	remaining: 14.8s
# 1000:	learn: 0.0668901	test: 183621.5080080	best: 183621.5079796 (569)	total: 2.56s	remaining: 5.12s
# Stopped by overfitting detector  (750 iterations wait)
#
# bestTest = 183621.5078
# bestIteration = 1068
#
# Shrink model to first 1069 iterations.
# 7 FOLD NMAE = 0.09194256941566724
#
# 8 FOLD Training.....
# 0:	learn: 0.2912342	test: 179670.4120383	best: 179670.4120383 (0)	total: 2.59ms	remaining: 7.78s
# Stopped by overfitting detector  (750 iterations wait)
#
# bestTest = 179670.3873
# bestIteration = 72
#
# Shrink model to first 73 iterations.
# 8 FOLD NMAE = 0.11695129992656782
#
# 9 FOLD Training.....
# 0:	learn: 0.2925163	test: 175656.7159184	best: 175656.7159184 (0)	total: 3.34ms	remaining: 10s
# Stopped by overfitting detector  (750 iterations wait)
#
# bestTest = 175656.6984
# bestIteration = 85
#
# Shrink model to first 86 iterations.
# 9 FOLD NMAE = 0.11768722146080494
#
# 10 FOLD Training.....
# 0:	learn: 0.2880924	test: 196335.7007966	best: 196335.7007966 (0)	total: 3.07ms	remaining: 9.22s
# Stopped by overfitting detector  (750 iterations wait)
#
# bestTest = 196335.6195
# bestIteration = 129
#
# Shrink model to first 130 iterations.
# 10 FOLD NMAE = 0.11973931306199619
#
# 10FOLD Mean of NMAE = 0.1216383184096956 & std = 0.05937168473550696

# %%
# ngboost
ngb_pred = np.zeros(target.shape[0])
ngb_val = []
for n, (tr_idx, val_idx) in enumerate(kf.split(X, y)) :
    print(f'{n + 1} FOLD Training.....')
    tr_x, tr_y = X.iloc[tr_idx], y.iloc[tr_idx]
    val_x, val_y = X.iloc[val_idx], np.expm1(y.iloc[val_idx])
    
    ngb = NGBRegressor(random_state = 42, n_estimators = 1000, verbose = 0, learning_rate = 0.03)
    ngb.fit(tr_x, tr_y, val_x, val_y, early_stopping_rounds = 300)
    
    val_pred = np.expm1(ngb.predict(val_x))
    val_nmae = NMAE(val_y, val_pred)
    ngb_val.append(val_nmae)
    print(f'{n + 1} FOLD NMAE = {val_nmae}\n')
    
    target_data = Pool(data = target, label = None)
    fold_pred = ngb.predict(target) / 10
    ngb_pred += fold_pred
print(f'10FOLD Mean of NMAE = {np.mean(ngb_val)} & std = {np.std(ngb_val)}')
# Out:
# 1 FOLD Training.....
# 1 FOLD NMAE = 0.07759123821384555
#
# 2 FOLD Training.....
# 2 FOLD NMAE = 0.09838485905746261
#
# 3 FOLD Training.....
# 3 FOLD NMAE = 0.09881404545829854
#
# 4 FOLD Training.....
# 4 FOLD NMAE = 0.10678691078675713
#
# 5 FOLD Training.....
# 5 FOLD NMAE = 0.08748296290849022
#
# 6 FOLD Training.....
# 6 FOLD NMAE = 0.10044471313753561
#
# 7 FOLD Training.....
# 7 FOLD NMAE = 0.0948358937007788
#
# 8 FOLD Training.....
# 8 FOLD NMAE = 0.09194441948718975
#
# 9 FOLD Training.....
# 9 FOLD NMAE = 0.0885833690411214
#
# 10 FOLD Training.....
# 10 FOLD NMAE = 0.0953867328416775
#
# 10FOLD Mean of NMAE = 0.09402551446331572 & std = 0.007715835741467004

# %%
np.exp((ngb_pred + cb_pred + rf_pred + gbr_pred) / 4)
# Out:
# array([325539.64004664, 131934.43073157, 176394.31576   , ...,
#         80456.51411983, 198593.63817291, 136370.33102249])

# %%
submission['target'] = np.expm1((ngb_pred + cb_pred + rf_pred + gbr_pred) / 4)

# %%
np.exp(ngb_pred)

# %%
submission['target'] = np.exp(ngb_pred)

# %%
submission
# Out:
#         id         target
# 0        1  337229.361199
# 1        2  130971.872148
# 2        3  177784.774309
# 3        4  247967.072247
# 4        5  133861.341429
# 5        6  149115.488352
# 6        7  191852.868232
# 7        8  119025.250145
# 8        9  138874.054617
# 9       10  302768.101520
# 10      11  228541.661369
# 11      12  127593.492615
# 12      13  166100.545569
# 13      14  126977.356738
# 14      15  106140.293019
# 15      16  134210.958747
# 16      17  125681.115311
# 17      18  189881.663626
# 18      19  194447.971069
# 19      20  131672.689596
# 20      21  144590.453143
# 21      22  126105.174066
# 22      23  172465.010668
# 23      24  253632.798045
# 24      25  186688.111286
# 25      26  340334.561729
# 26      27  153465.756741
# 27      28  236238.360808
# 28      29  139528.580080
# 29      30   71198.202343
# ...    ...            ...
# 1320  1321  163347.842062
# 1321  1322  221985.355058
# 1322  1323  177637.477453
# 1323  1324  192822.950264
# 1324  1325  135308.818202
# 1325  1326  154339.364969
# 1326  1327  128783.834536
# 1327  1328  107593.811751
# 1328  1329  327516.727505
# 1329  1330  299795.861252
# 1330  1331  122484.753707
# 1331  1332  146589.357209
# 1332  1333  131825.350065
# 1333  1334  177421.623194
# 1334  1335  137903.575984
# 1335  1336  127993.274991
# 1336  1337  198794.924477
# 1337  1338  280201.589027
# 1338  1339  172013.154454
# 1339  1340  215143.139816
# 1340  1341  206468.996699
# 1341  1342  187181.253393
# 1342  1343  121756.496720
# 1343  1344  340622.209733
# 1344  1345  231735.106859
# 1345  1346  340663.420341
# 1346  1347  126486.666660
# 1347  1348   77362.061623
# 1348  1349  196987.558300
# 1349  1350  128177.111365
#
# [1350 rows x 2 columns]

# %%
submission.to_csv("../out/ngb/ngb1.csv", header = True, index = False)
